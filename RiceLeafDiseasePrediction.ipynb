# %% [markdown]
# <a href="https://colab.research.google.com/github/Khalid019/Detecting-Rice-Leaf-Disease-Using-Machine-Learning-and-Deep-Learning-Techniques/blob/main/RiceLeafDiseasePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#-------------------------------------------------------------#
import tensorflow as tf
from tensorflow.keras import models, layers
from matplotlib import pyplot as plt


from tensorflow import keras
from tensorflow.keras.models import Sequential

# %%
IMAZE_WIDTH = 3081
IMAGE_HEIGHT = 897 
BATCH_SIZE = 32

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/Sample_Data/rice_leaf_diseases",
    shuffle = True,
    image_size = (IMAGE_HEIGHT, IMAZE_WIDTH),
    batch_size= BATCH_SIZE
)
# Out:
# Found 120 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Bacterial leaf blight', 'Brown spot', 'Leaf smut']

# %%
# Now check the lenght of dataset
len(dataset)
# Out:
# 4

# %%
for image_batch, label_batch in dataset.take(1):
  print(image_batch.shape)
  print(label_batch.numpy())
# Out:
# (32, 897, 3081, 3)
# [2 2 0 2 2 0 2 0 2 2 1 1 1 1 1 0 2 2 1 1 2 2 1 0 2 1 0 1 0 0 1 2]

# %%
## Print first image
for image_batch, label_batch in dataset.take(1):
  print(image_batch[0])
# Out:
# tf.Tensor(
# [[[241. 237. 234.]
#   [241. 237. 234.]
#   [241. 237. 234.]
#   ...
#   [240. 233. 225.]
#   [240. 233. 225.]
#   [240. 233. 225.]]
#
#  [[241. 237. 234.]
#   [241. 237. 234.]
#   [241. 237. 234.]
#   ...
#   [239. 232. 224.]
#   [240. 233. 225.]
#   [239. 232. 224.]]
#
#  [[241. 237. 234.]
#   [241. 237. 234.]
#   [241. 237. 234.]
#   ...
#   [239. 232. 224.]
#   [240. 233. 225.]
#   [239. 232. 224.]]
#
#  ...
#
#  [[239. 234. 230.]
#   [239. 234. 230.]
#   [239. 234. 230.]
#   ...
#   [240. 233. 225.]
#   [240. 233. 225.]
#   [240. 233. 225.]]
#
#  [[241. 233. 230.]
#   [239. 234. 230.]
#   [240. 232. 229.]
#   ...
#   [240. 233. 225.]
#   [240. 233. 225.]
#   [239. 232. 224.]]
#
#  [[243. 233. 231.]
#   [240. 232. 229.]
#   [241. 231. 229.]
#   ...
#   [240. 233. 227.]
#   [241. 234. 228.]
#   [241. 234. 228.]]], shape=(897, 3081, 3), dtype=float32)

# %%
## Print first image using shape
for image_batch, label_batch in dataset.take(1):
  print(image_batch[0].shape)
# Out:
# (897, 3081, 3)

# %%
## Printing first image

for image_batch, label_batch in dataset.take(1):
  plt.imshow(image_batch[0].numpy().astype("uint8"))
  plt.title(class_names[label_batch[0]])
  plt.axis("off")

# %%
## Printing first image
plt.figure(figsize = (30, 10))
for image_batch, label_batch in dataset.take(1):
  for i in range(12):
    ax = plt.subplot(3, 4, i+1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")
