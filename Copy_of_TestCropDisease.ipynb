# %% [markdown]
# <a href="https://colab.research.google.com/github/Khalid019/Detecting-Rice-Leaf-Disease-Using-Machine-Learning-and-Deep-Learning-Techniques/blob/main/Copy_of_TestCropDisease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Library

# %%
## Mounting Google Drive
from google.colab import drive, files
drive.mount('/content/drive')
from __future__ import absolute_import, print_function,division, unicode_literals
import os.path
import glob
import shutil

import tensorflow as tf
assert tf.__version__.startswith('2')

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D,Flatten,MaxPooling2D,Dropout,Dense,Activation
from keras import regularizers
import keras

import numpy as np
import matplotlib.pyplot as plt
import pathlib
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load

# %%
BATCH_SIZE = 8
IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
data_path ="/content/drive/MyDrive/Sample_Data/rice_leaf_diseases/"
data_path = pathlib.Path(data_path)

CLASS_NAMES = np.array(['Bacterial Leaf Blight','Brown Spot','Leaf Smut'])

print('Class Names: ', CLASS_NAMES)
# Out:
# Class Names:  ['Bacterial Leaf Blight' 'Brown Spot' 'Leaf Smut']

# %%
train_path = '/content/drive/MyDrive/Sample_Data/rice_leaf_diseases/'
test_path = '/content/drive/MyDrive/Sample_Data/rice_leaf_diseases/'

# %%
image_train_gen = ImageDataGenerator(rescale=1./255,
                                     zoom_range=0.50,
                                     rotation_range=45,
                                     horizontal_flip=True,
                                     width_shift_range=0.15,
                                     height_shift_range=0.15)

train_data_gen = image_train_gen.flow_from_directory(train_path,
                                                     shuffle=True,
                                                     batch_size=BATCH_SIZE,
                                                     target_size=(IMG_HEIGHT,IMG_WIDTH),
                                                     class_mode='sparse')

img_val_gen = ImageDataGenerator(rescale=1./255)
val_data_gen = img_val_gen.flow_from_directory(test_path,
                                               batch_size=BATCH_SIZE,
                                               target_size=(IMG_HEIGHT,IMG_WIDTH),
                                               class_mode='sparse')
# Out:
# Found 120 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
def plotImages(image_arr):
    fig,axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img,ax in zip(image_arr,axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()



# Plot a few training images
img_array = [train_data_gen[0][0][0] for i in range(5)]
plotImages(img_array)

# %%
# plot a few val images
img_array  = [val_data_gen[0][0][0] for i in range(5)]
plotImages(img_array)

# %%
# Model building
#Instatiating A convnet

model = Sequential()
model.add(Conv2D(16, (3,3), input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Conv2D(32, (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Conv2D(64, (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(128,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(3, activation="softmax"))

model.compile(
    optimizer = "adam",
    loss = "sparse_categorical_crossentropy",
    metrics = ['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 43264)             0
#
#  dropout (Dropout)           (None, 43264)             0
#
#  dense (Dense)               (None, 128)               5537920
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 5,561,891
# Trainable params: 5,561,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS=70
history = model.fit_generator(train_data_gen, epochs=EPOCHS, validation_data=val_data_gen)
# Out:
# <ipython-input-11-7786d5f387fe>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_data_gen, epochs=EPOCHS, validation_data=val_data_gen)
# Epoch 1/70
# 15/15 [==============================] - 46s 3s/step - loss: 1.6425 - accuracy: 0.3333 - val_loss: 1.1011 - val_accuracy: 0.4833
# Epoch 2/70
# 15/15 [==============================] - 28s 2s/step - loss: 1.0980 - accuracy: 0.3333 - val_loss: 1.0653 - val_accuracy: 0.6083
# Epoch 3/70
# 15/15 [==============================] - 20s 1s/step - loss: 1.0830 - accuracy: 0.3833 - val_loss: 1.0512 - val_accuracy: 0.3417
# Epoch 4/70
# 15/15 [==============================] - 18s 1s/step - loss: 1.0763 - accuracy: 0.4333 - val_loss: 1.0673 - val_accuracy: 0.5000
# Epoch 5/70
# 15/15 [==============================] - 22s 1s/step - loss: 1.0942 - accuracy: 0.4083 - val_loss: 0.9337 - val_accuracy: 0.7000
# Epoch 6/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.9963 - accuracy: 0.4750 - val_loss: 0.8721 - val_accuracy: 0.6917
# Epoch 7/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.9297 - accuracy: 0.5917 - val_loss: 1.1127 - val_accuracy: 0.5000
# Epoch 8/70
# 15/15 [==============================] - 24s 2s/step - loss: 1.0699 - accuracy: 0.5667 - val_loss: 1.1776 - val_accuracy: 0.4333
# Epoch 9/70
# 15/15 [==============================] - 25s 2s/step - loss: 0.9067 - accuracy: 0.5833 - val_loss: 0.8346 - val_accuracy: 0.6333
# Epoch 10/70
# 15/15 [==============================] - 18s 1s/step - loss: 0.8606 - accuracy: 0.6083 - val_loss: 0.7584 - val_accuracy: 0.6917
# Epoch 11/70
# 15/15 [==============================] - 25s 2s/step - loss: 0.8396 - accuracy: 0.5917 - val_loss: 0.7260 - val_accuracy: 0.6917
# Epoch 12/70
# 15/15 [==============================] - 20s 1s/step - loss: 0.7464 - accuracy: 0.6667 - val_loss: 0.7386 - val_accuracy: 0.6917
# Epoch 13/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.8757 - accuracy: 0.6750 - val_loss: 0.9122 - val_accuracy: 0.5333
# Epoch 14/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.9096 - accuracy: 0.5917 - val_loss: 0.7958 - val_accuracy: 0.6500
# Epoch 15/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.8061 - accuracy: 0.6333 - val_loss: 0.6911 - val_accuracy: 0.7250
# Epoch 16/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.7651 - accuracy: 0.6917 - val_loss: 0.6462 - val_accuracy: 0.7250
# Epoch 17/70
# 15/15 [==============================] - 22s 1s/step - loss: 0.8851 - accuracy: 0.5750 - val_loss: 0.6845 - val_accuracy: 0.7667
# Epoch 18/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.7656 - accuracy: 0.6333 - val_loss: 0.6465 - val_accuracy: 0.7417
# Epoch 19/70
# 15/15 [==============================] - 19s 1s/step - loss: 0.7376 - accuracy: 0.6833 - val_loss: 0.6154 - val_accuracy: 0.7500
# Epoch 20/70
# 15/15 [==============================] - 19s 1s/step - loss: 0.6773 - accuracy: 0.7417 - val_loss: 0.5733 - val_accuracy: 0.7333
# Epoch 21/70
# 15/15 [==============================] - 18s 1s/step - loss: 0.6462 - accuracy: 0.7083 - val_loss: 0.6034 - val_accuracy: 0.7500
# Epoch 22/70
# 15/15 [==============================] - 25s 2s/step - loss: 0.7962 - accuracy: 0.7000 - val_loss: 0.5727 - val_accuracy: 0.7583
# Epoch 23/70
# 15/15 [==============================] - 20s 1s/step - loss: 0.7255 - accuracy: 0.6750 - val_loss: 0.6989 - val_accuracy: 0.7417
# Epoch 24/70
# 15/15 [==============================] - 25s 2s/step - loss: 0.7481 - accuracy: 0.6750 - val_loss: 0.7298 - val_accuracy: 0.6667
# Epoch 25/70
# 15/15 [==============================] - 22s 1s/step - loss: 0.6937 - accuracy: 0.7167 - val_loss: 0.5748 - val_accuracy: 0.7667
# Epoch 26/70
# 15/15 [==============================] - 22s 2s/step - loss: 0.6835 - accuracy: 0.6667 - val_loss: 0.5560 - val_accuracy: 0.7583
# Epoch 27/70
# 15/15 [==============================] - 18s 1s/step - loss: 0.6822 - accuracy: 0.6917 - val_loss: 0.5396 - val_accuracy: 0.7833
# Epoch 28/70
# 15/15 [==============================] - 25s 2s/step - loss: 0.7812 - accuracy: 0.6667 - val_loss: 0.5728 - val_accuracy: 0.7583
# Epoch 29/70
# 15/15 [==============================] - 18s 1s/step - loss: 0.6611 - accuracy: 0.7083 - val_loss: 0.8825 - val_accuracy: 0.5750
# Epoch 30/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.7460 - accuracy: 0.6833 - val_loss: 0.5385 - val_accuracy: 0.7833
# Epoch 31/70
# 15/15 [==============================] - 19s 1s/step - loss: 0.6572 - accuracy: 0.6917 - val_loss: 0.5295 - val_accuracy: 0.7417
# Epoch 32/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.5479 - accuracy: 0.7833 - val_loss: 0.4670 - val_accuracy: 0.7917
# Epoch 33/70
# 15/15 [==============================] - 22s 2s/step - loss: 0.5810 - accuracy: 0.7333 - val_loss: 0.6733 - val_accuracy: 0.7000
# Epoch 34/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.8473 - accuracy: 0.6000 - val_loss: 0.8785 - val_accuracy: 0.5750
# Epoch 35/70
# 15/15 [==============================] - 20s 1s/step - loss: 0.8113 - accuracy: 0.6333 - val_loss: 0.6949 - val_accuracy: 0.7083
# Epoch 36/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.6680 - accuracy: 0.7083 - val_loss: 0.5389 - val_accuracy: 0.7833
# Epoch 37/70
# 15/15 [==============================] - 25s 2s/step - loss: 0.6230 - accuracy: 0.7000 - val_loss: 0.5085 - val_accuracy: 0.7750
# Epoch 38/70
# 15/15 [==============================] - 19s 1s/step - loss: 0.6657 - accuracy: 0.6917 - val_loss: 0.4760 - val_accuracy: 0.7917
# Epoch 39/70
# 15/15 [==============================] - 20s 1s/step - loss: 0.5540 - accuracy: 0.7333 - val_loss: 0.4362 - val_accuracy: 0.8500
# Epoch 40/70
# 15/15 [==============================] - 19s 1s/step - loss: 0.5112 - accuracy: 0.7583 - val_loss: 0.4052 - val_accuracy: 0.8167
# Epoch 41/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.4671 - accuracy: 0.7833 - val_loss: 0.3877 - val_accuracy: 0.8167
# Epoch 42/70
# 15/15 [==============================] - 18s 1s/step - loss: 0.5952 - accuracy: 0.7083 - val_loss: 0.4270 - val_accuracy: 0.8083
# Epoch 43/70
# 15/15 [==============================] - 20s 1s/step - loss: 0.5421 - accuracy: 0.7417 - val_loss: 0.4538 - val_accuracy: 0.8083
# Epoch 44/70
# 15/15 [==============================] - 22s 2s/step - loss: 0.5796 - accuracy: 0.7917 - val_loss: 0.4095 - val_accuracy: 0.8583
# Epoch 45/70
# 15/15 [==============================] - 21s 1s/step - loss: 0.5883 - accuracy: 0.7500 - val_loss: 0.4940 - val_accuracy: 0.7750
# Epoch 46/70
# 15/15 [==============================] - 21s 1s/step - loss: 0.6658 - accuracy: 0.7250 - val_loss: 0.5036 - val_accuracy: 0.8083
# Epoch 47/70
# 15/15 [==============================] - 21s 1s/step - loss: 0.6026 - accuracy: 0.7333 - val_loss: 0.4639 - val_accuracy: 0.7917
# Epoch 48/70
# 15/15 [==============================] - 17s 1s/step - loss: 0.5964 - accuracy: 0.7583 - val_loss: 0.6220 - val_accuracy: 0.7917
# Epoch 49/70
# 15/15 [==============================] - 19s 1s/step - loss: 0.6461 - accuracy: 0.7167 - val_loss: 0.4656 - val_accuracy: 0.8083
# Epoch 50/70
# 15/15 [==============================] - 18s 1s/step - loss: 0.5542 - accuracy: 0.7750 - val_loss: 0.4305 - val_accuracy: 0.8917
# Epoch 51/70
# 15/15 [==============================] - 20s 1s/step - loss: 0.4831 - accuracy: 0.8417 - val_loss: 0.3753 - val_accuracy: 0.8667
# Epoch 52/70
# 15/15 [==============================] - 18s 1s/step - loss: 0.4061 - accuracy: 0.8250 - val_loss: 0.3033 - val_accuracy: 0.8833
# Epoch 53/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.4291 - accuracy: 0.8000 - val_loss: 0.2843 - val_accuracy: 0.9000
# Epoch 54/70
# 15/15 [==============================] - 22s 2s/step - loss: 0.4651 - accuracy: 0.8167 - val_loss: 0.3563 - val_accuracy: 0.8500
# Epoch 55/70
# 15/15 [==============================] - 23s 2s/step - loss: 0.4777 - accuracy: 0.7917 - val_loss: 0.3476 - val_accuracy: 0.8333
# Epoch 56/70
# 15/15 [==============================] - 17s 1s/step - loss: 0.4346 - accuracy: 0.8000 - val_loss: 0.3582 - val_accuracy: 0.8500
# Epoch 57/70
# 15/15 [==============================] - 17s 1s/step - loss: 0.4938 - accuracy: 0.7833 - val_loss: 0.3306 - val_accuracy: 0.8583
# Epoch 58/70
# 15/15 [==============================] - 24s 2s/step - loss: 0.4899 - accuracy: 0.7750 - val_loss: 0.3919 - val_accuracy: 0.8667
# Epoch 59/70
# 15/15 [==============================] - 24s 2s/step - loss: 0.5453 - accuracy: 0.7417 - val_loss: 0.3912 - val_accuracy: 0.8583
# Epoch 60/70
# 15/15 [==============================] - 19s 1s/step - loss: 0.4482 - accuracy: 0.8250 - val_loss: 0.3172 - val_accuracy: 0.8167
# Epoch 61/70
# 15/15 [==============================] - 21s 1s/step - loss: 0.4202 - accuracy: 0.8000 - val_loss: 0.2752 - val_accuracy: 0.8917
# Epoch 62/70
# 15/15 [==============================] - 22s 1s/step - loss: 0.4165 - accuracy: 0.8250 - val_loss: 0.2606 - val_accuracy: 0.9000
# Epoch 63/70
# 15/15 [==============================] - 22s 2s/step - loss: 0.4938 - accuracy: 0.8000 - val_loss: 0.3538 - val_accuracy: 0.8250
# Epoch 64/70
# 15/15 [==============================] - 22s 2s/step - loss: 0.5030 - accuracy: 0.7750 - val_loss: 0.3075 - val_accuracy: 0.8583
# Epoch 65/70
# 15/15 [==============================] - 21s 1s/step - loss: 0.4332 - accuracy: 0.8250 - val_loss: 0.2863 - val_accuracy: 0.8500
# Epoch 66/70
# 15/15 [==============================] - 17s 1s/step - loss: 0.3690 - accuracy: 0.8333 - val_loss: 0.2572 - val_accuracy: 0.9000
# Epoch 67/70
# 15/15 [==============================] - 20s 1s/step - loss: 0.4383 - accuracy: 0.8167 - val_loss: 0.3757 - val_accuracy: 0.8583
# Epoch 68/70
# 15/15 [==============================] - 19s 1s/step - loss: 0.4656 - accuracy: 0.8333 - val_loss: 0.2775 - val_accuracy: 0.8917
# Epoch 69/70
# 15/15 [==============================] - 21s 1s/step - loss: 0.4436 - accuracy: 0.7917 - val_loss: 0.3424 - val_accuracy: 0.8583
# Epoch 70/70
# 15/15 [==============================] - 22s 2s/step - loss: 0.3681 - accuracy: 0.8417 - val_loss: 0.2537 - val_accuracy: 0.8750

# %%
# Plot training and validation graphs
acc = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(epochs_range,acc,label='Training Accuracy')
plt.plot(epochs_range,val_accuracy,label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,loss,label='Training Loss')
plt.plot(epochs_range,val_loss,label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
